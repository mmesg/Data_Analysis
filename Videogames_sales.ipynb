# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#pd.options.display.max_columns = 30
#pd.options.display.float_format = '{:.2f}'.format   # we set the float numbers to two decimals

# %% [markdown]
# ##### Source of the dataset:
# https://www.kaggle.com/datasets/gregorut/videogamesales?resource=download

# %%
df = pd.read_csv("vgsales.csv") # "Parse dates" converts dates from text to "Date" format

# %%
df     # Here we don't have a primary key, that is to say a unique value that identifies a specific row and column
# usually in the datasets the column "ID" is the primary key
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
# We delete the ""Rank" column from our dataset  - NOTE: we create a copy of the original dataset! 
# We don't touch the original dataset

df2 = df.drop(columns=['Rank']).copy()  #another way: df_new = df.drop('Rank', axis=1).copy()
df2
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16598 rows x 10 columns]

# %%
# We rename the column "Other_Sales" into "Other_Countries_Sales"

df2.rename(columns={'Other_Sales':'Other_Countries_Sales'}, inplace=True)
df2
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77
# 1          Platform    Nintendo     29.08      3.58      6.81
# 2            Racing    Nintendo     15.85     12.88      3.79
# 3            Sports    Nintendo     15.75     11.01      3.28
# 4      Role-Playing    Nintendo     11.27      8.89     10.22
# ...             ...         ...       ...       ...       ...
# 16593      Platform       Kemco      0.01      0.00      0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00
# 16595        Racing  Activision      0.00      0.00      0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Countries_Sales  Global_Sales
# 0                       8.46         82.74
# 1                       0.77         40.24
# 2                       3.31         35.82
# 3                       2.96         33.00
# 4                       1.00         31.37
# ...                      ...           ...
# 16593                   0.00          0.01
# 16594                   0.00          0.01
# 16595                   0.00          0.01
# 16596                   0.00          0.01
# 16597                   0.00          0.01
#
# [16598 rows x 10 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   16598 non-null  object
#  1   Platform               16598 non-null  object
#  2   Year                   16327 non-null  float64
#  3   Genre                  16598 non-null  object
#  4   Publisher              16540 non-null  object
#  5   NA_Sales               16598 non-null  float64
#  6   EU_Sales               16598 non-null  float64
#  7   JP_Sales               16598 non-null  float64
#  8   Other_Countries_Sales  16598 non-null  float64
#  9   Global_Sales           16598 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.3+ MB

# %%
# Since "Year" is a "float" Datatype, I want to convert it into a "integer" datatype. First let's make sure there are no
# NaN (not a number) values:

df2['Year'].isna().sum()
# Out:
# 271

# %%
# Since there are 271 NaN missing values, the conversion into integer wouldn't work. Hence we have to fill the NaN values 
# with "0"

df2['Year'] = df2['Year'].fillna(0)

# Now we can convert the column "Year" from float into integer:
df2['Year'] = df2['Year'].astype('int')

df2.info()
# Now we can see that the variable "Year" has the new datatype "integer":
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   16598 non-null  object
#  1   Platform               16598 non-null  object
#  2   Year                   16598 non-null  int32
#  3   Genre                  16598 non-null  object
#  4   Publisher              16540 non-null  object
#  5   NA_Sales               16598 non-null  float64
#  6   EU_Sales               16598 non-null  float64
#  7   JP_Sales               16598 non-null  float64
#  8   Other_Countries_Sales  16598 non-null  float64
#  9   Global_Sales           16598 non-null  float64
# dtypes: float64(5), int32(1), object(4)
# memory usage: 1.2+ MB

# %%
df2
# Out:
#                                                    Name Platform  Year  \
# 0                                            Wii Sports      Wii  2006
# 1                                     Super Mario Bros.      NES  1985
# 2                                        Mario Kart Wii      Wii  2008
# 3                                     Wii Sports Resort      Wii  2009
# 4                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594                     Men in Black II: Alien Escape       GC  2003
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596                                        Know How 2       DS  2010
# 16597                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77
# 1          Platform    Nintendo     29.08      3.58      6.81
# 2            Racing    Nintendo     15.85     12.88      3.79
# 3            Sports    Nintendo     15.75     11.01      3.28
# 4      Role-Playing    Nintendo     11.27      8.89     10.22
# ...             ...         ...       ...       ...       ...
# 16593      Platform       Kemco      0.01      0.00      0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00
# 16595        Racing  Activision      0.00      0.00      0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Countries_Sales  Global_Sales
# 0                       8.46         82.74
# 1                       0.77         40.24
# 2                       3.31         35.82
# 3                       2.96         33.00
# 4                       1.00         31.37
# ...                      ...           ...
# 16593                   0.00          0.01
# 16594                   0.00          0.01
# 16595                   0.00          0.01
# 16596                   0.00          0.01
# 16597                   0.00          0.01
#
# [16598 rows x 10 columns]

# %%
 # SUMMARY STATISTICS ON NUMERICAL COLUMNS
df2.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16598.000000  16598.000000  16598.000000
# mean    1973.647307      0.264667      0.146652      0.077782
# std      254.346809      0.816683      0.505351      0.309291
# min        0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000
# 75%     2010.000000      0.240000      0.110000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000
#
#        Other_Countries_Sales  Global_Sales
# count           16598.000000  16598.000000
# mean                0.048063      0.537441
# std                 0.188588      1.555028
# min                 0.000000      0.010000
# 25%                 0.000000      0.060000
# 50%                 0.010000      0.170000
# 75%                 0.040000      0.470000
# max                10.570000     82.740000

# %%
# We create a new dataframe in which the column "Name" is the index: this column will be the reference column in this
# new dataframe

df3 = df2.copy()
df3.set_index("Name", inplace = True)

# %%
df3
# Out:
#                                                  Platform  Year         Genre  \
# Name
# Wii Sports                                            Wii  2006        Sports
# Super Mario Bros.                                     NES  1985      Platform
# Mario Kart Wii                                        Wii  2008        Racing
# Wii Sports Resort                                     Wii  2009        Sports
# Pokemon Red/Pokemon Blue                               GB  1996  Role-Playing
# ...                                                   ...   ...           ...
# Woody Woodpecker in Crazy Castle 5                    GBA  2002      Platform
# Men in Black II: Alien Escape                          GC  2003       Shooter
# SCORE International Baja 1000: The Official Game      PS2  2008        Racing
# Know How 2                                             DS  2010        Puzzle
# Spirits & Spells                                      GBA  2003      Platform
#
#                                                    Publisher  NA_Sales  \
# Name
# Wii Sports                                          Nintendo     41.49
# Super Mario Bros.                                   Nintendo     29.08
# Mario Kart Wii                                      Nintendo     15.85
# Wii Sports Resort                                   Nintendo     15.75
# Pokemon Red/Pokemon Blue                            Nintendo     11.27
# ...                                                      ...       ...
# Woody Woodpecker in Crazy Castle 5                     Kemco      0.01
# Men in Black II: Alien Escape                     Infogrames      0.01
# SCORE International Baja 1000: The Official Game  Activision      0.00
# Know How 2                                          7G//AMES      0.00
# Spirits & Spells                                     Wanadoo      0.01
#
#                                                   EU_Sales  JP_Sales  \
# Name
# Wii Sports                                           29.02      3.77
# Super Mario Bros.                                     3.58      6.81
# Mario Kart Wii                                       12.88      3.79
# Wii Sports Resort                                    11.01      3.28
# Pokemon Red/Pokemon Blue                              8.89     10.22
# ...                                                    ...       ...
# Woody Woodpecker in Crazy Castle 5                    0.00      0.00
# Men in Black II: Alien Escape                         0.00      0.00
# SCORE International Baja 1000: The Official Game      0.00      0.00
# Know How 2                                            0.01      0.00
# Spirits & Spells                                      0.00      0.00
#
#                                                   Other_Countries_Sales  \
# Name
# Wii Sports                                                         8.46
# Super Mario Bros.                                                  0.77
# Mario Kart Wii                                                     3.31
# Wii Sports Resort                                                  2.96
# Pokemon Red/Pokemon Blue                                           1.00
# ...                                                                 ...
# Woody Woodpecker in Crazy Castle 5                                 0.00
# Men in Black II: Alien Escape                                      0.00
# SCORE International Baja 1000: The Official Game                   0.00
# Know How 2                                                         0.00
# Spirits & Spells                                                   0.00
#
#                                                   Global_Sales
# Name
# Wii Sports                                               82.74
# Super Mario Bros.                                        40.24
# Mario Kart Wii                                           35.82
# Wii Sports Resort                                        33.00
# Pokemon Red/Pokemon Blue                                 31.37
# ...                                                        ...
# Woody Woodpecker in Crazy Castle 5                        0.01
# Men in Black II: Alien Escape                             0.01
# SCORE International Baja 1000: The Official Game          0.01
# Know How 2                                                0.01
# Spirits & Spells                                          0.01
#
# [16598 rows x 9 columns]

# %% [markdown]
# ## Which games are best sellers?

# %%
#We create a function that shows the games that are best sellers

# n = how many games we want to have displayed in the ranking? Let's say 10
# by = by which criterium do we want to sort the best videogames?  We chose the criterium "Region"

def best_seller(n, by, ascending = False, min_sales=0):

    df4 = df3.loc[(df3.Global_Sales>min_sales) & (df3.EU_Sales>min_sales) & (df3.NA_Sales>min_sales) 
                     & (df3.JP_Sales>min_sales) & (df3.Other_Countries_Sales>min_sales),  ["Platform", "Genre", "Year",by]].sort_values(by = by, ascending=False).head(n).copy()
    return df4

# %%
best_seller(n = 10, by = "JP_Sales")
# Out:
#                                             Platform         Genre  Year  \
# Name
# Pokemon Red/Pokemon Blue                          GB  Role-Playing  1996
# Pokemon Gold/Pokemon Silver                       GB  Role-Playing  1999
# Super Mario Bros.                                NES      Platform  1985
# New Super Mario Bros.                             DS      Platform  2006
# Pokemon Diamond/Pokemon Pearl                     DS  Role-Playing  2006
# Pokemon Black/Pokemon White                       DS  Role-Playing  2010
# Pokemon Ruby/Pokemon Sapphire                    GBA  Role-Playing  2002
# Animal Crossing: Wild World                       DS    Simulation  2005
# Brain Age 2: More Training in Minutes a Day       DS        Puzzle  2005
# New Super Mario Bros. Wii                        Wii      Platform  2009
#
#                                              JP_Sales
# Name
# Pokemon Red/Pokemon Blue                        10.22
# Pokemon Gold/Pokemon Silver                      7.20
# Super Mario Bros.                                6.81
# New Super Mario Bros.                            6.50
# Pokemon Diamond/Pokemon Pearl                    6.04
# Pokemon Black/Pokemon White                      5.65
# Pokemon Ruby/Pokemon Sapphire                    5.38
# Animal Crossing: Wild World                      5.33
# Brain Age 2: More Training in Minutes a Day      5.32
# New Super Mario Bros. Wii                        4.70

# %%
best_seller(n = 10, by = "EU_Sales")
# Out:
#                                              Platform         Genre  Year  \
# Name
# Wii Sports                                        Wii        Sports  2006
# Mario Kart Wii                                    Wii        Racing  2008
# Wii Sports Resort                                 Wii        Sports  2009
# Nintendogs                                         DS    Simulation  2005
# Grand Theft Auto V                                PS3        Action  2013
# Brain Age: Train Your Brain in Minutes a Day       DS          Misc  2005
# New Super Mario Bros.                              DS      Platform  2006
# Wii Play                                          Wii          Misc  2006
# Pokemon Red/Pokemon Blue                           GB  Role-Playing  1996
# Wii Fit Plus                                      Wii        Sports  2009
#
#                                               EU_Sales
# Name
# Wii Sports                                       29.02
# Mario Kart Wii                                   12.88
# Wii Sports Resort                                11.01
# Nintendogs                                       11.00
# Grand Theft Auto V                                9.27
# Brain Age: Train Your Brain in Minutes a Day      9.26
# New Super Mario Bros.                             9.23
# Wii Play                                          9.20
# Pokemon Red/Pokemon Blue                          8.89
# Wii Fit Plus                                      8.59

# %%
best_seller(n = 10, by = "NA_Sales")
# Out:
#                           Platform     Genre  Year  NA_Sales
# Name
# Wii Sports                     Wii    Sports  2006     41.49
# Super Mario Bros.              NES  Platform  1985     29.08
# Duck Hunt                      NES   Shooter  1984     26.93
# Tetris                          GB    Puzzle  1989     23.20
# Mario Kart Wii                 Wii    Racing  2008     15.85
# Wii Sports Resort              Wii    Sports  2009     15.75
# Kinect Adventures!            X360      Misc  2010     14.97
# New Super Mario Bros. Wii      Wii  Platform  2009     14.59
# Wii Play                       Wii      Misc  2006     14.03
# Super Mario World             SNES  Platform  1990     12.78

# %%
best_seller(n = 10, by = "Other_Countries_Sales")
# Out:
#                               Platform       Genre  Year  \
# Name
# Grand Theft Auto: San Andreas      PS2      Action  2004
# Wii Sports                         Wii      Sports  2006
# Gran Turismo 4                     PS2      Racing  2004
# Grand Theft Auto V                 PS3      Action  2013
# Mario Kart Wii                     Wii      Racing  2008
# Wii Sports Resort                  Wii      Sports  2009
# New Super Mario Bros.               DS    Platform  2006
# Wii Play                           Wii        Misc  2006
# Nintendogs                          DS  Simulation  2005
# Call of Duty: Black Ops II         PS3     Shooter  2012
#
#                                Other_Countries_Sales
# Name
# Grand Theft Auto: San Andreas                  10.57
# Wii Sports                                      8.46
# Gran Turismo 4                                  7.53
# Grand Theft Auto V                              4.14
# Mario Kart Wii                                  3.31
# Wii Sports Resort                               2.96
# New Super Mario Bros.                           2.90
# Wii Play                                        2.85
# Nintendogs                                      2.75
# Call of Duty: Black Ops II                      2.52

# %%
best_seller(n = 10, by = "Global_Sales")
# Out:
#                           Platform         Genre  Year  Global_Sales
# Name
# Wii Sports                     Wii        Sports  2006         82.74
# Super Mario Bros.              NES      Platform  1985         40.24
# Mario Kart Wii                 Wii        Racing  2008         35.82
# Wii Sports Resort              Wii        Sports  2009         33.00
# Pokemon Red/Pokemon Blue        GB  Role-Playing  1996         31.37
# Tetris                          GB        Puzzle  1989         30.26
# New Super Mario Bros.           DS      Platform  2006         30.01
# Wii Play                       Wii          Misc  2006         29.02
# New Super Mario Bros. Wii      Wii      Platform  2009         28.62
# Duck Hunt                      NES       Shooter  1984         28.31

# %%
df3
# Out:
#                                                  Platform  Year         Genre  \
# Name
# Wii Sports                                            Wii  2006        Sports
# Super Mario Bros.                                     NES  1985      Platform
# Mario Kart Wii                                        Wii  2008        Racing
# Wii Sports Resort                                     Wii  2009        Sports
# Pokemon Red/Pokemon Blue                               GB  1996  Role-Playing
# ...                                                   ...   ...           ...
# Woody Woodpecker in Crazy Castle 5                    GBA  2002      Platform
# Men in Black II: Alien Escape                          GC  2003       Shooter
# SCORE International Baja 1000: The Official Game      PS2  2008        Racing
# Know How 2                                             DS  2010        Puzzle
# Spirits & Spells                                      GBA  2003      Platform
#
#                                                    Publisher  NA_Sales  \
# Name
# Wii Sports                                          Nintendo     41.49
# Super Mario Bros.                                   Nintendo     29.08
# Mario Kart Wii                                      Nintendo     15.85
# Wii Sports Resort                                   Nintendo     15.75
# Pokemon Red/Pokemon Blue                            Nintendo     11.27
# ...                                                      ...       ...
# Woody Woodpecker in Crazy Castle 5                     Kemco      0.01
# Men in Black II: Alien Escape                     Infogrames      0.01
# SCORE International Baja 1000: The Official Game  Activision      0.00
# Know How 2                                          7G//AMES      0.00
# Spirits & Spells                                     Wanadoo      0.01
#
#                                                   EU_Sales  JP_Sales  \
# Name
# Wii Sports                                           29.02      3.77
# Super Mario Bros.                                     3.58      6.81
# Mario Kart Wii                                       12.88      3.79
# Wii Sports Resort                                    11.01      3.28
# Pokemon Red/Pokemon Blue                              8.89     10.22
# ...                                                    ...       ...
# Woody Woodpecker in Crazy Castle 5                    0.00      0.00
# Men in Black II: Alien Escape                         0.00      0.00
# SCORE International Baja 1000: The Official Game      0.00      0.00
# Know How 2                                            0.01      0.00
# Spirits & Spells                                      0.00      0.00
#
#                                                   Other_Countries_Sales  \
# Name
# Wii Sports                                                         8.46
# Super Mario Bros.                                                  0.77
# Mario Kart Wii                                                     3.31
# Wii Sports Resort                                                  2.96
# Pokemon Red/Pokemon Blue                                           1.00
# ...                                                                 ...
# Woody Woodpecker in Crazy Castle 5                                 0.00
# Men in Black II: Alien Escape                                      0.00
# SCORE International Baja 1000: The Official Game                   0.00
# Know How 2                                                         0.00
# Spirits & Spells                                                   0.00
#
#                                                   Global_Sales
# Name
# Wii Sports                                               82.74
# Super Mario Bros.                                        40.24
# Mario Kart Wii                                           35.82
# Wii Sports Resort                                        33.00
# Pokemon Red/Pokemon Blue                                 31.37
# ...                                                        ...
# Woody Woodpecker in Crazy Castle 5                        0.01
# Men in Black II: Alien Escape                             0.01
# SCORE International Baja 1000: The Official Game          0.01
# Know How 2                                                0.01
# Spirits & Spells                                          0.01
#
# [16598 rows x 9 columns]

# %%
# Frequencies of the gaming platforms in the whole dataset: which gaming platforms appear most?

df3["Platform"].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
# Frequencies of the gaming genre in the whole dataset: which genre appear most?

df3["Genre"].value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
# What are the gaming platforms appearing in this dataset?

df3["Platform"].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# ## Find a game
# ### Search 1: "Mario" games

# %%
# As next task we want to get relevant information about all "Mario" games.
# We will start from the dataframe "df2" and we will obtain a smaller dataframe that displays only "Mario" games

# %%
df2
# Out:
#                                                    Name Platform  Year  \
# 0                                            Wii Sports      Wii  2006
# 1                                     Super Mario Bros.      NES  1985
# 2                                        Mario Kart Wii      Wii  2008
# 3                                     Wii Sports Resort      Wii  2009
# 4                              Pokemon Red/Pokemon Blue       GB  1996
# ...                                                 ...      ...   ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594                     Men in Black II: Alien Escape       GC  2003
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596                                        Know How 2       DS  2010
# 16597                                  Spirits & Spells      GBA  2003
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77
# 1          Platform    Nintendo     29.08      3.58      6.81
# 2            Racing    Nintendo     15.85     12.88      3.79
# 3            Sports    Nintendo     15.75     11.01      3.28
# 4      Role-Playing    Nintendo     11.27      8.89     10.22
# ...             ...         ...       ...       ...       ...
# 16593      Platform       Kemco      0.01      0.00      0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00
# 16595        Racing  Activision      0.00      0.00      0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Countries_Sales  Global_Sales
# 0                       8.46         82.74
# 1                       0.77         40.24
# 2                       3.31         35.82
# 3                       2.96         33.00
# 4                       1.00         31.37
# ...                      ...           ...
# 16593                   0.00          0.01
# 16594                   0.00          0.01
# 16595                   0.00          0.01
# 16596                   0.00          0.01
# 16597                   0.00          0.01
#
# [16598 rows x 10 columns]

# %%
# the following lines give as results non-mario games as well, e.g. "Detective Conad marionette"
# This means the search includes words that contain "mario" but are not the word "mario". 


mario_games= df2.Name.str.contains("Mario")  
mario_games
df2.loc[mario_games, ["Name", "Year", "Platform", "Global_Sales"]]
# Out:
#                                                     Name  Year Platform  \
# 1                                      Super Mario Bros.  1985      NES
# 2                                         Mario Kart Wii  2008      Wii
# 6                                  New Super Mario Bros.  2006       DS
# 8                              New Super Mario Bros. Wii  2009      Wii
# 11                                         Mario Kart DS  2005       DS
# ...                                                  ...   ...      ...
# 12770       Dance Dance Revolution: Mario Mix (JP sales)  2005       GC
# 13273               Detective Conan: Marionette Symphony  2013      3DS
# 15261                                       Mario Tennis     0      3DS
# 16357               Mario vs. Donkey Kong: Tipping Stars  2015     WiiU
# 16542  Mario & Luigi: Paper Jam & Mario Kart 7 Double...  2015      3DS
#
#        Global_Sales
# 1             40.24
# 2             35.82
# 6             30.01
# 8             28.62
# 11            23.42
# ...             ...
# 12770          0.06
# 13273          0.05
# 15261          0.02
# 16357          0.01
# 16542          0.01
#
# [113 rows x 4 columns]

# %%
# We have to change the search criteria.
# In the command below we add diacritics to regex, to make sure that the search is only for the word "Mario"

mario_games= df2.Name.str.contains(('(?:\s|^|[,;])Mario(?:\s|$|[,;])'))  

mario_games
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 16593    False
# 16594    False
# 16595    False
# 16596    False
# 16597    False
# Name: Name, Length: 16598, dtype: bool

# %%
df2.loc[mario_games, ["Name", "Platform"]]
# Out:
#                                                     Name Platform
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 6                                  New Super Mario Bros.       DS
# 8                              New Super Mario Bros. Wii      Wii
# 11                                         Mario Kart DS       DS
# ...                                                  ...      ...
# 12373               Mario vs. Donkey Kong: Tipping Stars      3DS
# 12770       Dance Dance Revolution: Mario Mix (JP sales)       GC
# 15261                                       Mario Tennis      3DS
# 16357               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16542  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
# [109 rows x 2 columns]

# %% [markdown]
# ## Graphic representation of Mario games

# %%
#pd.options.display.max_rows = 20
df7 = df2.loc[mario_games, ["Name", "Global_Sales"]].head(20)
df7.set_index("Name", inplace = True)
df7
# Out:
#                                     Global_Sales
# Name
# Super Mario Bros.                          40.24
# Mario Kart Wii                             35.82
# New Super Mario Bros.                      30.01
# New Super Mario Bros. Wii                  28.62
# Mario Kart DS                              23.42
# Super Mario World                          20.61
# Super Mario Land                           18.14
# Super Mario Bros. 3                        17.28
# Mario Kart 7                               12.21
# Super Mario 64                             11.89
# Super Mario Galaxy                         11.52
# Super Mario Land 2: 6 Golden Coins         11.18
# Super Mario 3D Land                        10.79
# Super Mario All-Stars                      10.55
# Super Mario 64                             10.42
# Mario Kart 64                               9.87
# New Super Mario Bros. 2                     9.82
# Mario Party DS                              9.02
# Super Mario Kart                            8.76
# Mario Party 8                               8.42

# %%
df8 = df7.sort_values(by='Global_Sales').copy()
df8
# Out:
#                                     Global_Sales
# Name
# Mario Party 8                               8.42
# Super Mario Kart                            8.76
# Mario Party DS                              9.02
# New Super Mario Bros. 2                     9.82
# Mario Kart 64                               9.87
# Super Mario 64                             10.42
# Super Mario All-Stars                      10.55
# Super Mario 3D Land                        10.79
# Super Mario Land 2: 6 Golden Coins         11.18
# Super Mario Galaxy                         11.52
# Super Mario 64                             11.89
# Mario Kart 7                               12.21
# Super Mario Bros. 3                        17.28
# Super Mario Land                           18.14
# Super Mario World                          20.61
# Mario Kart DS                              23.42
# New Super Mario Bros. Wii                  28.62
# New Super Mario Bros.                      30.01
# Mario Kart Wii                             35.82
# Super Mario Bros.                          40.24

# %%
import matplotlib.pyplot as plt
import numpy as np 

df8.plot(kind='barh',figsize = (20, 15), width=0.5, fontsize = 20)
plt.tick_params(axis='y', which='major', labelsize=20)
plt.title("Mario Best Seller", fontsize = 40)
plt.show()

# %%
# What is the platform that created most "Mario" games?

df6 = df2.loc[mario_games, ["Name", "Platform"]]
df6["Platform"].value_counts().copy()
# Out:
# Wii     16
# GBA     16
# 3DS     14
# GC      12
# DS      11
# N64      9
# WiiU     9
# SNES     8
# GB       7
# NES      6
# 2600     1
# Name: Platform, dtype: int64

# %% [markdown]
# # Wordclouds

# %%
from wordcloud import WordCloud

# %%
df2
wordcloud, interpolation= "bilinear")
plt.axis('off')
plt.show()

# %%
# The wordcloud above shows the ancient roman number "II" as biggest result: this is because the wordloud counted
# all games that hat a sequel game. Therefore for the next wordcloud I am going to remove all numbers that are the
# sequel of a game:
df4 = df2[df2["Name"].str.contains("I|II|III|IV|V|1|2|3|4|5|6") == False] 
df4
# Out:
#                                                     Name Platform  Year  \
# 0                                             Wii Sports      Wii  2006
# 1                                      Super Mario Bros.      NES  1985
# 2                                         Mario Kart Wii      Wii  2008
# 3                                      Wii Sports Resort      Wii  2009
# 4                               Pokemon Red/Pokemon Blue       GB  1996
# ...                                                  ...      ...   ...
# 16588                                   Mega Brain Boost       DS  2008
# 16589  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV  2016
# 16590  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP  2007
# 16592                                           Plushees       DS  2008
# 16597                                   Spirits & Spells      GBA  2003
#
#               Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0            Sports               Nintendo     41.49     29.02      3.77
# 1          Platform               Nintendo     29.08      3.58      6.81
# 2            Racing               Nintendo     15.85     12.88      3.79
# 3            Sports               Nintendo     15.75     11.01      3.28
# 4      Role-Playing               Nintendo     11.27      8.89     10.22
# ...             ...                    ...       ...       ...       ...
# 16588        Puzzle  Majesco Entertainment      0.01      0.00      0.00
# 16589        Action        dramatic create      0.00      0.00      0.01
# 16590  Role-Playing     Falcom Corporation      0.00      0.00      0.01
# 16592    Simulation              Destineer      0.01      0.00      0.00
# 16597      Platform                Wanadoo      0.01      0.00      0.00
#
#        Other_Countries_Sales  Global_Sales
# 0                       8.46         82.74
# 1                       0.77         40.24
# 2                       3.31         35.82
# 3                       2.96         33.00
# 4                       1.00         31.37
# ...                      ...           ...
# 16588                   0.00          0.01
# 16589                   0.00          0.01
# 16590                   0.00          0.01
# 16592                   0.00          0.01
# 16597                   0.00          0.01
#
# [10598 rows x 10 columns]

# %%
name = df4.Name
games = " ".join(name)
games
# Out:
# "Wii Sports Super Mario Bros. Mario Kart Wii Wii Sports Resort Pokemon Red/Pokemon Blue Tetris New Super Mario Bros. Wii Play New Super Mario Bros. Wii Duck Hunt Nintendogs Mario Kart DS Pokemon Gold/Pokemon Silver Wii Fit Wii Fit Plus Kinect Adventures! Grand Theft Auto: San Andreas Super Mario World Brain Age: Train Your Brain in Minutes a Day Pokemon Diamond/Pokemon Pearl Super Mario Land Pokemon Ruby/Pokemon Sapphire Pokemon Black/Pokemon White Pokémon Yellow: Special Pikachu Edition Call of Duty: Black Ops Pokemon X/Pokemon Y Super Smash Bros. Brawl Call of Duty: Black Ops Animal Crossing: Wild World Mario Kart 7 Pokemon HeartGold/Pokemon SoulSilver Super Mario Galaxy Pokemon Omega Ruby/Pokemon Alpha Sapphire Gran Turismo Super Mario All-Stars Pokemon FireRed/Pokemon LeafGreen Call of Duty: Ghosts Halo: Reach Call of Duty: Ghosts Donkey Kong Country Minecraft Animal Crossing: New Leaf Mario Party DS Super Mario Kart Wii Party Mario Party 8 GoldenEye 007 Mario & Sonic at the Olympic Games Final Fantasy X Pac-Man Grand Theft Auto: Liberty City Stories Call of Duty: Advanced Warfare The Legend of Zelda: Ocarina of Time Call of Duty: World at War